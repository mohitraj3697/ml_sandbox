# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df.shape
# Out:
# (100, 4)

# %%
df=df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %% [markdown]
# # Steps
#
# # 0. Preprocess + EDA + Feature Selection
# # 1. Extract input and output cols
# # 2. Train test split
# # 3. Scale the values
# # 4. Train the model
# # 5. Evaluate the model/model selection
# # 6. Deploy the model

# %% [markdown]
# 1

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %% [markdown]
# 1

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
X.shape
# Out:
# (100, 2)

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y.shape
# Out:
# (100,)

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %% [markdown]
# 2

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 32   7.0  139.0
# 29   7.0  112.0
# 54   6.4  141.0
# 41   5.4  114.0
# 36   5.7  140.0
# ..   ...    ...
# 92   5.2  110.0
# 21   7.1  151.0
# 12   5.4  139.0
# 77   7.3   50.0
# 47   5.2  161.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 32    1
# 29    1
# 54    1
# 41    0
# 36    0
#      ..
# 92    0
# 21    1
# 12    0
# 77    1
# 47    0
# Name: placement, Length: 90, dtype: int64

# %%
X_test
# Out:
#     cgpa     iq
# 51   4.8  141.0
# 89   4.9  151.0
# 64   7.0   64.0
# 62   6.0  102.0
# 30   7.6  128.0
# 95   4.3  200.0
# 40   4.9  134.0
# 67   5.0  118.0
# 19   5.2  132.0
# 44   7.5   61.0

# %%
y_test
# Out:
# 51    0
# 89    0
# 64    1
# 62    0
# 30    1
# 95    0
# 40    0
# 67    0
# 19    0
# 44    1
# Name: placement, dtype: int64

# %% [markdown]
# 3

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 0.86503643,  0.38564122],
#        [ 0.86503643, -0.29194964],
#        [ 0.33482114,  0.43583313],
#        [-0.54887101, -0.24175773],
#        [-0.28376337,  0.41073717],
#        [ 0.688298  , -0.01589411],
#        [-0.81397866,  0.10958568],
#        [ 0.77666721, -0.69348496],
#        [-0.72560944, -0.84406071],
#        [-0.19539415,  1.06323207],
#        [ 0.688298  , -0.84406071],
#        [-0.99071709,  0.78717654],
#        [ 1.13014407, -0.94444454],
#        [-2.2278861 ,  2.74466123],
#        [ 0.06971349, -0.51781326],
#        [ 1.13014407, -0.19156581],
#        [ 0.95340564, -1.89809093],
#        [-2.40462453,  1.48986335],
#        [-0.90234787, -0.81896475],
#        [ 2.19057465, -0.09118198],
#        [-0.28376337,  1.13851995],
#        [-0.28376337,  0.20996951],
#        [-0.63724023, -0.24175773],
#        [-0.72560944,  2.51879762],
#        [ 0.33482114, -0.19156581],
#        [-0.99071709, -1.57184348],
#        [-0.01865572,  0.63660079],
#        [-1.0790863 ,  1.13851995],
#        [ 0.77666721,  0.36054526],
#        [-0.19539415,  0.46092909],
#        [ 0.42319035, -2.17414646],
#        [ 0.24645192, -0.51781326],
#        [-0.54887101, -0.41742943],
#        [ 0.59992878,  0.76208058],
#        [-0.81397866,  1.31419165],
#        [ 1.3068825 ,  0.86246441],
#        [-1.78604002, -1.22050007],
#        [-1.16745552, -0.06608602],
#        [-1.16745552, -0.91934858],
#        [ 1.83709779,  0.63660079],
#        [ 1.3068825 ,  0.1597776 ],
#        [-0.10702494, -0.44252539],
#        [-0.90234787, -1.52165157],
#        [-0.63724023, -0.06608602],
#        [ 0.77666721,  0.38564122],
#        [-1.43256316, -2.04866668],
#        [ 0.42319035, -0.84406071],
#        [ 1.39525172, -0.86915667],
#        [ 0.688298  , -0.29194964],
#        [ 0.42319035,  0.1597776 ],
#        [ 0.86503643,  1.89139867],
#        [ 0.86503643,  1.28909569],
#        [-0.01865572, -1.9733788 ],
#        [-1.78604002, -0.59310113],
#        [ 1.13014407,  0.3354493 ],
#        [ 0.15808271, -0.26685368],
#        [ 2.01383622,  1.11342399],
#        [ 0.42319035,  0.91265633],
#        [ 0.24645192,  0.10958568],
#        [ 0.688298  ,  0.43583313],
#        [ 0.06971349, -1.47145965],
#        [-0.99071709, -0.09118198],
#        [ 0.51155957, -0.09118198],
#        [-1.16745552, -1.7977071 ],
#        [ 0.24645192,  0.08448972],
#        [ 0.06971349,  0.20996951],
#        [-0.01865572, -1.44636369],
#        [ 0.06971349, -1.06992433],
#        [-1.0790863 , -0.29194964],
#        [-0.81397866, -1.44636369],
#        [-0.28376337,  0.48602505],
#        [-1.25582473,  0.56131292],
#        [ 1.57199015, -0.24175773],
#        [-0.01865572,  0.00920185],
#        [-1.43256316,  0.63660079],
#        [ 0.06971349,  0.8122725 ],
#        [-1.87440924, -0.36723751],
#        [-0.54887101,  0.28525739],
#        [ 1.21851329,  0.20996951],
#        [-0.99071709,  1.8161108 ],
#        [ 1.74872858, -1.12011624],
#        [ 1.83709779,  1.06323207],
#        [ 0.59992878,  1.46476739],
#        [-1.0790863 ,  0.9879442 ],
#        [ 0.51155957,  0.36054526],
#        [-0.72560944, -0.34214156],
#        [ 0.95340564,  0.68679271],
#        [-0.54887101,  0.38564122],
#        [ 1.13014407, -1.84789901],
#        [-0.72560944,  0.93775228]])

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[-1.0790863 ,  0.43583313],
#        [-0.99071709,  0.68679271],
#        [ 0.86503643, -1.49655561],
#        [-0.01865572, -0.54290922],
#        [ 1.39525172,  0.10958568],
#        [-1.52093238,  1.91649463],
#        [-0.99071709,  0.26016143],
#        [-0.90234787, -0.14137389],
#        [-0.72560944,  0.20996951],
#        [ 1.3068825 , -1.57184348]])

# %% [markdown]
# 4

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %% [markdown]
# model train

# %%
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# 5

# %%
y_pred = clf.predict(X_test)

# %%
y_test
# Out:
# 51    0
# 89    0
# 64    1
# 62    0
# 30    1
# 95    0
# 40    0
# 67    0
# 19    0
# 44    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >
